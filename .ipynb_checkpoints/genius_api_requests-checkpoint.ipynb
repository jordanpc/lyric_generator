# %%
import requests
from bs4 import BeautifulSoup
from lastfm_api import gettoptracks
import numpy as np
import datetime
import requests
from pprint import pprint
import pandas as pd
import os
import json

# %%
# api key for last.fm
API_KEY = '395ba12d921dee55ad263b4c8b53dfc7'

BEARER_TOKEN = "hLLUI0D7QaKVaulNUbThPLC_JDjr9c3BrufGEcyw6C9FpW4YDNqHc1NOgaBspgkW"
client_id = "ts8I1lK-3eAlvDw33cI2PbWYVXa9pE4Q2aSUeIWcWSei02MKLYkkL4F-Q7F1U6Id"
client_access = "QchBo2tCBes7AWgA7LNJLQ0LvG_HV5Py6qj3nZ2YgsmumzCUqcGWY8BCt7rL6psr"

base_url = "http://api.genius.com"
headers = {'Authorization': 'Bearer hLLUI0D7QaKVaulNUbThPLC_JDjr9c3BrufGEcyw6C9FpW4YDNqHc1NOgaBspgkW'}

# %%
#function to run API request and HTML parsing
def lyrics_from_song_api_path(song_api_path):
    song_url = base_url + song_api_path
    response = requests.get(song_url, headers=headers)
    json = response.json()
    path = json["response"]["song"]["path"]
    page_url = "http://genius.com" + path
    page = requests.get(page_url)
    html = BeautifulSoup(page.text, "html.parser")
    [h.extract() for h in html('script')]
    lyrics = html.find("div", class_= "lyrics").get_text() 
    return lyrics

# %%
# generate 30*50 = 1500 tracks with the gettoptrack function
tracks = gettoptracks(1)
tracks['api_path'] = ""
tracks.head()
print(f'the total # of tracks is {len(tracks)}')
# Out:
# the total # of tracks is 50

# %%
tracks
# Out:
#    rank             artist_name                    song_title genres
# 0     1                   Oasis                    Wonderwall    pop
# 1     2             The Killers              Somebody Told Me    pop
# 2     3                Coldplay                  Viva la Vida    pop
# 3     4                Coldplay                        Clocks    pop
# 4     5                Coldplay                 The Scientist    pop
# 5     6                    MGMT                          Kids    pop
# 6     7                Coldplay                        Yellow    pop
# 7     8                Coldplay                       Fix You    pop
# 8     9                Gorillaz                Feel Good Inc.    pop
# 9    10               Lady Gaga                    Poker Face    pop
# 10   11             Snow Patrol                  Chasing Cars    pop
# 11   12                   Ke$ha                       TiK ToK    pop
# 12   13           Goo Goo Dolls                          Iris    pop
# 13   14              Jason Mraz                     I'm Yours    pop
# 14   15                   Adele           Rolling in the Deep    pop
# 15   16                Gorillaz                Clint Eastwood    pop
# 16   17       Foster the People               Pumped Up Kicks    pop
# 17   18         Michael Jackson                   Billie Jean    pop
# 18   19              Katy Perry               I Kissed a Girl    pop
# 19   20                  R.E.M.            Losing My Religion    pop
# 20   21             The Killers        Smile Like You Mean It    pop
# 21   22           Amy Winehouse                         Rehab    pop
# 22   23           Amy Winehouse                 Back to Black    pop
# 23   24               The Verve         Bitter Sweet Symphony    pop
# 24   25                Coldplay                   Don't Panic    pop
# 25   26                The Fray            How to Save a Life    pop
# 26   27                Maroon 5             She Will Be Loved    pop
# 27   28                  M.I.A.                  Paper Planes    pop
# 28   29      The Postal Service            Such Great Heights    pop
# 29   30               Lady Gaga                   Bad Romance    pop
# 30   31                    a-ha                    Take on Me    pop
# 31   32                Coldplay                   In My Place    pop
# 32   33  Florence + the Machine             Dog Days Are Over    pop
# 33   34                Coldplay                       Trouble    pop
# 34   35          Gnarls Barkley                         Crazy    pop
# 35   36                Coldplay                Speed of Sound    pop
# 36   37              Kanye West                     Heartless    pop
# 37   38               Lady Gaga                     Paparazzi    pop
# 38   39                   Keane        Somewhere Only We Know    pop
# 39   40                Maroon 5                     This Love    pop
# 40   41                Gorillaz                          DARE    pop
# 41   42           Amy Winehouse          You Know I'm No Good    pop
# 42   43         Michael Jackson                      Thriller    pop
# 43   44                   Gotye  Somebody That I Used To Know    pop
# 44   45                The Cure            Friday I'm in Love    pop
# 45   46               Lady Gaga                    Just Dance    pop
# 46   47                      U2           With or Without You    pop
# 47   48                Coldplay                   Violet Hill    pop
# 48   49       Simon & Garfunkel          The Sound of Silence    pop
# 49   50             The Beatles                 Come Together    pop

# %%
for i,row in tracks.iterrows():
    song_title = row['song_title']
    artist_name = row['artist_name']
    base_url = "http://api.genius.com"
    url = f'{base_url}/search'
    params = {'q': song_title}
    response = requests.get(url, params=params, headers=headers)
    data = response.json()
    api_path = None
    hits_list = data['response']['hits']
    for item in hits_list:
        name = item['result']['primary_artist']['name']
        if name == artist_name:
            api_path = item['result']['api_path']
            tracks.loc[i,'api_path'] = api_path
            break
    if api_path is None:
        tracks.loc[i,'api_path'] = "Not Available"

# %%
tracks.head(20)
# Out:
#    rank        artist_name           song_title genres       api_path
# 0     1              Oasis           Wonderwall    pop   /songs/76654
# 1     2        The Killers     Somebody Told Me    pop   /songs/88230
# 2     3           Coldplay         Viva la Vida    pop   /songs/49192
# 3     4           Coldplay               Clocks    pop   /songs/53753
# 4     5           Coldplay        The Scientist    pop   /songs/77594
# 5     6               MGMT                 Kids    pop  Not Available
# 6     7           Coldplay               Yellow    pop   /songs/77782
# 7     8           Coldplay              Fix You    pop   /songs/79647
# 8     9           Gorillaz       Feel Good Inc.    pop   /songs/21569
# 9    10          Lady Gaga           Poker Face    pop    /songs/1316
# 10   11        Snow Patrol         Chasing Cars    pop  /songs/102032
# 11   12              Ke$ha              TiK ToK    pop  Not Available
# 12   13      Goo Goo Dolls                 Iris    pop  /songs/138482
# 13   14         Jason Mraz            I'm Yours    pop   /songs/58874
# 14   15              Adele  Rolling in the Deep    pop   /songs/61289
# 15   16           Gorillaz       Clint Eastwood    pop    /songs/1698
# 16   17  Foster the People      Pumped Up Kicks    pop  Not Available
# 17   18    Michael Jackson          Billie Jean    pop    /songs/1644
# 18   19         Katy Perry      I Kissed a Girl    pop  /songs/130024
# 19   20             R.E.M.   Losing My Religion    pop   /songs/64232

# %%
tracks['lyrics'] = ''
for i,row in tracks.iterrows():
    api_path = row['api_path']
    base_url = "http://api.genius.com"
    if api_path == 'Not Available':
        tracks.loc[i,'lyrics'] = 'Not Available'
    else:
        lyrics = lyrics_from_song_api_path(api_path)
        tracks.loc[i,'lyrics'] = lyrics

# %%
tracks
# Out:
#    rank             artist_name                    song_title genres  \
# 0     1                   Oasis                    Wonderwall    pop
# 1     2             The Killers              Somebody Told Me    pop
# 2     3                Coldplay                  Viva la Vida    pop
# 3     4                Coldplay                        Clocks    pop
# 4     5                Coldplay                 The Scientist    pop
# 5     6                    MGMT                          Kids    pop
# 6     7                Coldplay                        Yellow    pop
# 7     8                Coldplay                       Fix You    pop
# 8     9                Gorillaz                Feel Good Inc.    pop
# 9    10               Lady Gaga                    Poker Face    pop
# 10   11             Snow Patrol                  Chasing Cars    pop
# 11   12                   Ke$ha                       TiK ToK    pop
# 12   13           Goo Goo Dolls                          Iris    pop
# 13   14              Jason Mraz                     I'm Yours    pop
# 14   15                   Adele           Rolling in the Deep    pop
# 15   16                Gorillaz                Clint Eastwood    pop
# 16   17       Foster the People               Pumped Up Kicks    pop
# 17   18         Michael Jackson                   Billie Jean    pop
# 18   19              Katy Perry               I Kissed a Girl    pop
# 19   20                  R.E.M.            Losing My Religion    pop
# 20   21             The Killers        Smile Like You Mean It    pop
# 21   22           Amy Winehouse                         Rehab    pop
# 22   23           Amy Winehouse                 Back to Black    pop
# 23   24               The Verve         Bitter Sweet Symphony    pop
# 24   25                Coldplay                   Don't Panic    pop
# 25   26                The Fray            How to Save a Life    pop
# 26   27                Maroon 5             She Will Be Loved    pop
# 27   28                  M.I.A.                  Paper Planes    pop
# 28   29      The Postal Service            Such Great Heights    pop
# 29   30               Lady Gaga                   Bad Romance    pop
# 30   31                    a-ha                    Take on Me    pop
# 31   32                Coldplay                   In My Place    pop
# 32   33  Florence + the Machine             Dog Days Are Over    pop
# 33   34                Coldplay                       Trouble    pop
# 34   35          Gnarls Barkley                         Crazy    pop
# 35   36                Coldplay                Speed of Sound    pop
# 36   37              Kanye West                     Heartless    pop
# 37   38               Lady Gaga                     Paparazzi    pop
# 38   39                   Keane        Somewhere Only We Know    pop
# 39   40                Maroon 5                     This Love    pop
# 40   41                Gorillaz                          DARE    pop
# 41   42           Amy Winehouse          You Know I'm No Good    pop
# 42   43         Michael Jackson                      Thriller    pop
# 43   44                   Gotye  Somebody That I Used To Know    pop
# 44   45                The Cure            Friday I'm in Love    pop
# 45   46               Lady Gaga                    Just Dance    pop
# 46   47                      U2           With or Without You    pop
# 47   48                Coldplay                   Violet Hill    pop
# 48   49       Simon & Garfunkel          The Sound of Silence    pop
# 49   50             The Beatles                 Come Together    pop
#
#          api_path                                             lyrics
# 0    /songs/76654  \n\n[Verse 1]\nToday is gonna be the day that ...
# 1    /songs/88230  \n\n[Verse 1]\nBreaking my back just to know y...
# 2    /songs/49192  \n\n[Verse 1]\nI used to rule the world\nSeas ...
# 3    /songs/53753  \n\n[Verse 1]\nThe lights go out and I can't b...
# 4    /songs/77594  \n\n[Verse 1]\nCome up to meet you, tell you I...
# 5   Not Available                                      Not Available
# 6    /songs/77782  \n\n[Verse 1]\nLook at the stars\nLook how the...
# 7    /songs/79647  \n\n[Verse 1]\nWhen you try your best, but you...
# 8    /songs/21569  \n\n[Intro: Trugoy the Dove & 2D]\nHa-ha-ha-ha...
