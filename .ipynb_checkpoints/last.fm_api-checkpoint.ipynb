# %% [markdown]
# ### Generate a list of Saturday between defined period

# %%
# import dependencies
import numpy as np
import datetime
import requests
from pprint import pprint
import pandas as pd
import os
import json

# %%
# define a function to generate the closest saturday of our desired date
def getsaturday(date):
    "@date: given date, in format '2013-05-25'"
    d1 = datetime.datetime.strptime(date, '%Y-%m-%d')
    t = datetime.timedelta((7 + 5 - d1.weekday()) % 7) # 5 is saturday
    next_saturday = d1 + t
    return next_saturday

# %%
# function to calculate the range for the for loop to generate list
def getdaterange(startdate, lastdate):
    "@startdate & lastdate: given date, in format '2013-05-25'"
    d1 = getsaturday(startdate)
    d2 = datetime.datetime.strptime(lastdate,'%Y-%m-%d')
    date_range = (d2 - d1).days/7
    return int(date_range)+1

# %%
def getdatelist(startdate, lastdate):
    "@startdate & lastdate: given date, in format '2013-05-25'"
    "@generate a list of saturday between the date range"
    # Create a list to store all saturdays
    date_list = []
    #date1 = datetime.datetime.strptime(start_date, '%Y-%m-%d')
    #date2 = datetime.datetime.strptime(last_date, '%Y-%m-%d')
    d1 = getsaturday(start_date)
    d2 = getsaturday(last_date)
    n = getdaterange(start_date, last_date)
    aweekago = datetime.timedelta(days=7)
    date_list.append(d2)
    date = d2 # define date as the last saturday of the datelist
    for i in range(n):
        new_date = date - aweekago
        date_list.append(new_date)
        date = new_date
    return date_list

# %% [markdown]
# ## Last.fm API to obtain list of artist & song name

# %%
# use last.fm API to generate a list of tags
API_KEY = '395ba12d921dee55ad263b4c8b53dfc7'
url = 'http://ws.audioscrobbler.com/2.0/'
tags_url = f'{url}?method=chart.gettoptags&api_key={API_KEY}&format=json'
response = requests.get(tags_url)

# %%
tags_df = pd.DataFrame(response.json()['tags']['tag'])
tags_df = tags_df.drop(columns=['streamable','wiki','url'])
tags_df['reach'] = pd.to_numeric(tags_df['reach'], errors='raise', downcast='integer')
tags_df = tags_df.sort_values(by=['reach'],ascending=False)
tags_df = tags_df.set_index('name',drop=True)
tags_df.head()
# Out:
#               reach taggings
# name
# rock         393237  3934195
# alternative  260105  2067975
# electronic   251520  2334148
# indie        251254  1994515
# pop          222658  1929570

# %%
tag_name = 'pop'
page = 1
tracksbytag_url = f'{url}?method=tag.gettoptracks&tag={tag_name}&api_key={API_KEY}&format=json&page={page}'
response = requests.get(tracksbytag_url)
data = response.json()
max_page = data['tracks']['@attr']['totalPages']
tracks = data['tracks']['track']
print(max_page)
# Out:
# 6198

# %%
pprint(data['tracks']['track'])
# Out:
# [{'@attr': {'rank': '1'},
#   'artist': {'mbid': 'ecf9f3a3-35e9-4c58-acaa-e707fba45060',
#              'name': 'Oasis',
#              'url': 'https://www.last.fm/music/Oasis'},
#   'duration': '259',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/08300481d8484150c13b769007cac3ef.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/08300481d8484150c13b769007cac3ef.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/08300481d8484150c13b769007cac3ef.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/08300481d8484150c13b769007cac3ef.png',
#              'size': 'extralarge'}],
#   'mbid': '31623cce-9717-4513-9d83-1b5d04e44f9b',
#   'name': 'Wonderwall',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Oasis/_/Wonderwall'},
#  {'@attr': {'rank': '2'},
#   'artist': {'mbid': '95e1ead9-4d31-4808-a7ac-32c3614c116b',
#              'name': 'The Killers',
#              'url': 'https://www.last.fm/music/The+Killers'},
#   'duration': '197',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'extralarge'}],
#   'mbid': '309eb50b-637b-476c-9f23-a589a90432fe',
#   'name': 'Somebody Told Me',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/The+Killers/_/Somebody+Told+Me'},
#  {'@attr': {'rank': '3'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '241',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': '6cbbb97d-2180-4ba9-97a8-6158b6332bb4',
#   'name': 'Viva la Vida',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Viva+la+Vida'},
#  {'@attr': {'rank': '4'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '310',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': 'ec87fef2-84cd-41b3-8642-38ce1b6962a6',
#   'name': 'Clocks',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Clocks'},
#  {'@attr': {'rank': '5'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '309',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': '13f5488d-8e41-42d8-9fe9-a5295f1a9a3d',
#   'name': 'The Scientist',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/The+Scientist'},
#  {'@attr': {'rank': '6'},
#   'artist': {'mbid': 'c485632c-b784-4ee9-8ea1-c5fb365681fc',
#              'name': 'MGMT',
#              'url': 'https://www.last.fm/music/MGMT'},
#   'duration': '288',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/be62578c6e6245f2a8cf49f5a33d8b06.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/be62578c6e6245f2a8cf49f5a33d8b06.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/be62578c6e6245f2a8cf49f5a33d8b06.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/be62578c6e6245f2a8cf49f5a33d8b06.png',
#              'size': 'extralarge'}],
#   'mbid': 'c741a7ef-dd33-4c79-a4d4-8745d9675620',
#   'name': 'Kids',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/MGMT/_/Kids'},
#  {'@attr': {'rank': '7'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '267',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': '8b5bf478-22f8-4902-a1c1-0db82261db58',
#   'name': 'Yellow',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Yellow'},
#  {'@attr': {'rank': '8'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '294',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': '3af0af54-9c93-4578-9128-d04054286ba3',
#   'name': 'Fix You',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Fix+You'},
#  {'@attr': {'rank': '9'},
#   'artist': {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596',
#              'name': 'Gorillaz',
#              'url': 'https://www.last.fm/music/Gorillaz'},
#   'duration': '221',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'extralarge'}],
#   'mbid': '5660558a-bfa7-416f-99d9-a34ca0a34515',
#   'name': 'Feel Good Inc.',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Gorillaz/_/Feel+Good+Inc.'},
#  {'@attr': {'rank': '10'},
#   'artist': {'mbid': '650e7db6-b795-4eb5-a702-5ea2fc46c848',
#              'name': 'Lady Gaga',
#              'url': 'https://www.last.fm/music/Lady+Gaga'},
#   'duration': '239',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'extralarge'}],
#   'mbid': 'c50edf48-ac2b-442f-b24f-d2acf775441c',
#   'name': 'Poker Face',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Lady+Gaga/_/Poker+Face'},
#  {'@attr': {'rank': '11'},
#   'artist': {'mbid': 'a66999a7-ae5c-460e-ba94-1a01143ae847',
#              'name': 'Snow Patrol',
#              'url': 'https://www.last.fm/music/Snow+Patrol'},
#   'duration': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/d5b0ebdf4892e21d69716d183d6095a4.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/d5b0ebdf4892e21d69716d183d6095a4.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/d5b0ebdf4892e21d69716d183d6095a4.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/d5b0ebdf4892e21d69716d183d6095a4.png',
#              'size': 'extralarge'}],
#   'mbid': 'f62a3798-6559-4f9b-8b80-6ea3e4ad89aa',
#   'name': 'Chasing Cars',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Snow+Patrol/_/Chasing+Cars'},
#  {'@attr': {'rank': '12'},
#   'artist': {'mbid': 'fab34286-b8e1-4879-bce3-194e1358fbd2',
#              'name': 'Ke$ha',
#              'url': 'https://www.last.fm/music/Ke$ha'},
#   'duration': '201',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/c5996ecb53bd50304a796a627b26a53f.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/c5996ecb53bd50304a796a627b26a53f.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/c5996ecb53bd50304a796a627b26a53f.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/c5996ecb53bd50304a796a627b26a53f.png',
#              'size': 'extralarge'}],
#   'mbid': '6a4999c9-de41-4025-9cdd-e1191e38499e',
#   'name': 'TiK ToK',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Ke$ha/_/TiK+ToK'},
#  {'@attr': {'rank': '13'},
#   'artist': {'mbid': 'e2c00c56-8365-4160-9f40-a64682917633',
#              'name': 'Goo Goo Dolls',
#              'url': 'https://www.last.fm/music/Goo+Goo+Dolls'},
#   'duration': '289',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/4b0826e9180a46e691810df6ef6c2763.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/4b0826e9180a46e691810df6ef6c2763.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/4b0826e9180a46e691810df6ef6c2763.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/4b0826e9180a46e691810df6ef6c2763.png',
#              'size': 'extralarge'}],
#   'mbid': '57d079a0-a195-453e-bb01-9ccff26a5de2',
#   'name': 'Iris',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Goo+Goo+Dolls/_/Iris'},
#  {'@attr': {'rank': '14'},
#   'artist': {'mbid': '82eb8936-7bf6-4577-8320-a2639465206d',
#              'name': 'Jason Mraz',
#              'url': 'https://www.last.fm/music/Jason+Mraz'},
#   'duration': '242',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/a510d6d484fb467fc689f37475e55a74.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/a510d6d484fb467fc689f37475e55a74.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/a510d6d484fb467fc689f37475e55a74.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/a510d6d484fb467fc689f37475e55a74.png',
#              'size': 'extralarge'}],
#   'mbid': 'a5a2330e-2fff-4601-a715-6e68a8e98fbf',
#   'name': "I'm Yours",
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Jason+Mraz/_/I%27m+Yours'},
#  {'@attr': {'rank': '15'},
#   'artist': {'mbid': 'cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493',
#              'name': 'Adele',
#              'url': 'https://www.last.fm/music/Adele'},
#   'duration': '229',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/5ed371a8b6d03258d597eb661805baee.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/5ed371a8b6d03258d597eb661805baee.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/5ed371a8b6d03258d597eb661805baee.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/5ed371a8b6d03258d597eb661805baee.png',
#              'size': 'extralarge'}],
#   'mbid': '1a13c710-4b7e-4701-8968-cd61f2e58110',
#   'name': 'Rolling in the Deep',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Adele/_/Rolling+in+the+Deep'},
#  {'@attr': {'rank': '16'},
#   'artist': {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596',
#              'name': 'Gorillaz',
#              'url': 'https://www.last.fm/music/Gorillaz'},
#   'duration': '339',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'extralarge'}],
#   'mbid': '77032ab7-10b3-4275-af00-9568ba3f47e3',
#   'name': 'Clint Eastwood',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Gorillaz/_/Clint+Eastwood'},
#  {'@attr': {'rank': '17'},
#   'artist': {'mbid': 'e0e1a584-dd0a-4bd1-88d1-c4c62895039d',
#              'name': 'Foster the People',
#              'url': 'https://www.last.fm/music/Foster+the+People'},
#   'duration': '236',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/f584bf97887743dfbdf4f0c456d1b831.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/f584bf97887743dfbdf4f0c456d1b831.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/f584bf97887743dfbdf4f0c456d1b831.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/f584bf97887743dfbdf4f0c456d1b831.png',
#              'size': 'extralarge'}],
#   'mbid': '816b3284-5f24-4f3a-9554-750e0bf5d060',
#   'name': 'Pumped Up Kicks',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Foster+the+People/_/Pumped+Up+Kicks'},
#  {'@attr': {'rank': '18'},
#   'artist': {'mbid': 'f27ec8db-af05-4f36-916e-3d57f91ecf5e',
#              'name': 'Michael Jackson',
#              'url': 'https://www.last.fm/music/Michael+Jackson'},
#   'duration': '293',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'extralarge'}],
#   'mbid': 'f980fc14-e29b-481d-ad3a-5ed9b4ab6340',
#   'name': 'Billie Jean',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Michael+Jackson/_/Billie+Jean'},
#  {'@attr': {'rank': '19'},
#   'artist': {'mbid': '122d63fc-8671-43e4-9752-34e846d62a9c',
#              'name': 'Katy Perry',
#              'url': 'https://www.last.fm/music/Katy+Perry'},
#   'duration': '181',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7dd5aec8565c7c429df8ed9d9b05c0aa.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7dd5aec8565c7c429df8ed9d9b05c0aa.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7dd5aec8565c7c429df8ed9d9b05c0aa.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7dd5aec8565c7c429df8ed9d9b05c0aa.png',
#              'size': 'extralarge'}],
#   'mbid': '9ed869d7-4297-4033-b47a-afe9476eebf2',
#   'name': 'I Kissed a Girl',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Katy+Perry/_/I+Kissed+a+Girl'},
#  {'@attr': {'rank': '20'},
#   'artist': {'mbid': 'ea4dfa26-f633-4da6-a52a-f49ea4897b58',
#              'name': 'R.E.M.',
#              'url': 'https://www.last.fm/music/R.E.M.'},
#   'duration': '301',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/13a34280bcd941d79554e8971dc2b391.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/13a34280bcd941d79554e8971dc2b391.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/13a34280bcd941d79554e8971dc2b391.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/13a34280bcd941d79554e8971dc2b391.png',
#              'size': 'extralarge'}],
#   'mbid': '04233db6-f991-4fb2-bef9-813f95a0bf30',
#   'name': 'Losing My Religion',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/R.E.M./_/Losing+My+Religion'},
#  {'@attr': {'rank': '21'},
#   'artist': {'mbid': '95e1ead9-4d31-4808-a7ac-32c3614c116b',
#              'name': 'The Killers',
#              'url': 'https://www.last.fm/music/The+Killers'},
#   'duration': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/298003c3bc07cb4b76eeadf4c9f54142.png',
#              'size': 'extralarge'}],
#   'mbid': '6cf8cc5d-0fb1-4bd4-bcec-d0e74de480e1',
#   'name': 'Smile Like You Mean It',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/The+Killers/_/Smile+Like+You+Mean+It'},
#  {'@attr': {'rank': '22'},
#   'artist': {'mbid': 'dfe9a7c4-8cf2-47f4-9dcb-d233c2b86ec3',
#              'name': 'Amy Winehouse',
#              'url': 'https://www.last.fm/music/Amy+Winehouse'},
#   'duration': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'extralarge'}],
#   'mbid': '873eba85-b721-4728-be2e-96ce94cccb8b',
#   'name': 'Rehab',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Amy+Winehouse/_/Rehab'},
#  {'@attr': {'rank': '23'},
#   'artist': {'mbid': 'dfe9a7c4-8cf2-47f4-9dcb-d233c2b86ec3',
#              'name': 'Amy Winehouse',
#              'url': 'https://www.last.fm/music/Amy+Winehouse'},
#   'duration': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'extralarge'}],
#   'mbid': 'b0adc7a8-0a90-4e09-8839-a66f315234a2',
#   'name': 'Back to Black',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Amy+Winehouse/_/Back+to+Black'},
#  {'@attr': {'rank': '24'},
#   'artist': {'mbid': 'd4d17620-fd97-4574-92a8-a2cb7e72ce42',
#              'name': 'The Verve',
#              'url': 'https://www.last.fm/music/The+Verve'},
#   'duration': '275',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7e0fa36faa3b4620b7df058dc0c19a6a.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7e0fa36faa3b4620b7df058dc0c19a6a.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7e0fa36faa3b4620b7df058dc0c19a6a.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7e0fa36faa3b4620b7df058dc0c19a6a.png',
#              'size': 'extralarge'}],
#   'mbid': '8b6d9029-1990-4660-bd57-24b5bc0fb626',
#   'name': 'Bitter Sweet Symphony',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/The+Verve/_/Bitter+Sweet+Symphony'},
#  {'@attr': {'rank': '25'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '141',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': 'fb81a071-9c63-4e8c-ab60-77403e81c01d',
#   'name': "Don't Panic",
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Don%27t+Panic'},
#  {'@attr': {'rank': '26'},
#   'artist': {'mbid': '2ddd167f-5b8a-4372-b350-6ad50493bac0',
#              'name': 'The Fray',
#              'url': 'https://www.last.fm/music/The+Fray'},
#   'duration': '290',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/1872f6e669484252bff3b720c04236de.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/1872f6e669484252bff3b720c04236de.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/1872f6e669484252bff3b720c04236de.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/1872f6e669484252bff3b720c04236de.png',
#              'size': 'extralarge'}],
#   'mbid': '5c5cae19-b26c-4542-907a-9c15b51ab6a6',
#   'name': 'How to Save a Life',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/The+Fray/_/How+to+Save+a+Life'},
#  {'@attr': {'rank': '27'},
#   'artist': {'mbid': '0ab49580-c84f-44d4-875f-d83760ea2cfe',
#              'name': 'Maroon 5',
#              'url': 'https://www.last.fm/music/Maroon+5'},
#   'duration': '379',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'extralarge'}],
#   'mbid': '0eb8495d-fc5e-4c32-8a6e-aea9ce9741cf',
#   'name': 'She Will Be Loved',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Maroon+5/_/She+Will+Be+Loved'},
#  {'@attr': {'rank': '28'},
#   'artist': {'mbid': 'b22d45dd-deae-4663-a782-542db02e25cf',
#              'name': 'M.I.A.',
#              'url': 'https://www.last.fm/music/M.I.A.'},
#   'duration': '203',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/4a6f97f398cf673b119d246fa56d55cf.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/4a6f97f398cf673b119d246fa56d55cf.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/4a6f97f398cf673b119d246fa56d55cf.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/4a6f97f398cf673b119d246fa56d55cf.png',
#              'size': 'extralarge'}],
#   'mbid': '09f03130-4b30-46d8-a2cd-81f8ef9bb97b',
#   'name': 'Paper Planes',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/M.I.A./_/Paper+Planes'},
#  {'@attr': {'rank': '29'},
#   'artist': {'mbid': '299278d3-25dd-4f30-bae4-5b571c28034d',
#              'name': 'The Postal Service',
#              'url': 'https://www.last.fm/music/The+Postal+Service'},
#   'duration': '262',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/04c140c3d9844b4dcb9c9a93e0f23448.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/04c140c3d9844b4dcb9c9a93e0f23448.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/04c140c3d9844b4dcb9c9a93e0f23448.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/04c140c3d9844b4dcb9c9a93e0f23448.png',
#              'size': 'extralarge'}],
#   'mbid': '276942c0-bbad-4e14-ac8e-6be5154c2d1a',
#   'name': 'Such Great Heights',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/The+Postal+Service/_/Such+Great+Heights'},
#  {'@attr': {'rank': '30'},
#   'artist': {'mbid': '650e7db6-b795-4eb5-a702-5ea2fc46c848',
#              'name': 'Lady Gaga',
#              'url': 'https://www.last.fm/music/Lady+Gaga'},
#   'duration': '261',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'extralarge'}],
#   'mbid': 'f0f34d5d-d7fc-44b0-aba8-7eca277882e2',
#   'name': 'Bad Romance',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Lady+Gaga/_/Bad+Romance'},
#  {'@attr': {'rank': '31'},
#   'artist': {'mbid': '7364dea6-ca9a-48e3-be01-b44ad0d19897',
#              'name': 'a-ha',
#              'url': 'https://www.last.fm/music/a-ha'},
#   'duration': '227',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/6d55da04b7314ef1a32be077c18abc1c.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/6d55da04b7314ef1a32be077c18abc1c.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/6d55da04b7314ef1a32be077c18abc1c.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/6d55da04b7314ef1a32be077c18abc1c.png',
#              'size': 'extralarge'}],
#   'mbid': 'c9bf13e6-619e-4cca-ae0f-512e9a478930',
#   'name': 'Take on Me',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/a-ha/_/Take+on+Me'},
#  {'@attr': {'rank': '32'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '226',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': 'f6b0d094-f2c3-476c-b4cc-f354cb377929',
#   'name': 'In My Place',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/In+My+Place'},
#  {'@attr': {'rank': '33'},
#   'artist': {'mbid': '5fee3020-513b-48c2-b1f7-4681b01db0c6',
#              'name': 'Florence + the Machine',
#              'url': 'https://www.last.fm/music/Florence+%252B+the+Machine'},
#   'duration': '270',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/412e31ae1cb0a3b1c9db4715509de8bc.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/412e31ae1cb0a3b1c9db4715509de8bc.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/412e31ae1cb0a3b1c9db4715509de8bc.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/412e31ae1cb0a3b1c9db4715509de8bc.png',
#              'size': 'extralarge'}],
#   'mbid': '772ea437-45b3-4868-b3c0-b80526ef0fa3',
#   'name': 'Dog Days Are Over',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Florence+%252B+the+Machine/_/Dog+Days+Are+Over'},
#  {'@attr': {'rank': '34'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': '99754a32-9dbd-4e39-b6af-6fccb7b0789d',
#   'name': 'Trouble',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Trouble'},
#  {'@attr': {'rank': '35'},
#   'artist': {'mbid': 'a47c3aa2-7d87-475c-a2c7-1e2047dafb09',
#              'name': 'Gnarls Barkley',
#              'url': 'https://www.last.fm/music/Gnarls+Barkley'},
#   'duration': '178',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/6f0ec4cd54d64155b66a060096ec5921.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/6f0ec4cd54d64155b66a060096ec5921.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/6f0ec4cd54d64155b66a060096ec5921.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/6f0ec4cd54d64155b66a060096ec5921.png',
#              'size': 'extralarge'}],
#   'mbid': '778c57f3-b103-4577-93e8-6d4a148dcdc4',
#   'name': 'Crazy',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Gnarls+Barkley/_/Crazy'},
#  {'@attr': {'rank': '36'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '266',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': 'cfaf1603-7c1b-4a96-8ce9-8d05567ecfe7',
#   'name': 'Speed of Sound',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Speed+of+Sound'},
#  {'@attr': {'rank': '37'},
#   'artist': {'mbid': '164f0d73-1234-4e2c-8743-d77bf2191051',
#              'name': 'Kanye West',
#              'url': 'https://www.last.fm/music/Kanye+West'},
#   'duration': '209',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/40e5c15607c7f22e7f83b3accd78446e.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/40e5c15607c7f22e7f83b3accd78446e.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/40e5c15607c7f22e7f83b3accd78446e.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/40e5c15607c7f22e7f83b3accd78446e.png',
#              'size': 'extralarge'}],
#   'mbid': 'a9c00a70-bbf1-4a19-be7e-bdb2d4daf456',
#   'name': 'Heartless',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Kanye+West/_/Heartless'},
#  {'@attr': {'rank': '38'},
#   'artist': {'mbid': '650e7db6-b795-4eb5-a702-5ea2fc46c848',
#              'name': 'Lady Gaga',
#              'url': 'https://www.last.fm/music/Lady+Gaga'},
#   'duration': '209',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'extralarge'}],
#   'mbid': '7a1040dc-bac0-479c-9921-f43797ed0b81',
#   'name': 'Paparazzi',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Lady+Gaga/_/Paparazzi'},
#  {'@attr': {'rank': '39'},
#   'artist': {'mbid': 'c7020c6d-cae9-4db3-92a7-e5c561cbad50',
#              'name': 'Keane',
#              'url': 'https://www.last.fm/music/Keane'},
#   'duration': '234',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/4eed298977c04dd1ad77e9c4d61e7a11.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/4eed298977c04dd1ad77e9c4d61e7a11.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/4eed298977c04dd1ad77e9c4d61e7a11.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/4eed298977c04dd1ad77e9c4d61e7a11.png',
#              'size': 'extralarge'}],
#   'mbid': '0868857f-740f-47c1-a2c7-b6323c185c63',
#   'name': 'Somewhere Only We Know',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Keane/_/Somewhere+Only+We+Know'},
#  {'@attr': {'rank': '40'},
#   'artist': {'mbid': '0ab49580-c84f-44d4-875f-d83760ea2cfe',
#              'name': 'Maroon 5',
#              'url': 'https://www.last.fm/music/Maroon+5'},
#   'duration': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/b52cbd4385188218d2e810bb2f472a39.png',
#              'size': 'extralarge'}],
#   'mbid': '1ee17f8d-5f82-408c-9d57-c4feb6658cb8',
#   'name': 'This Love',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Maroon+5/_/This+Love'},
#  {'@attr': {'rank': '41'},
#   'artist': {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596',
#              'name': 'Gorillaz',
#              'url': 'https://www.last.fm/music/Gorillaz'},
#   'duration': '244',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/71fa6cf85240bde8b1162b07e5f4ba61.png',
#              'size': 'extralarge'}],
#   'mbid': '7c146b44-4454-4429-9c27-01a6dc936fff',
#   'name': 'DARE',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Gorillaz/_/DARE'},
#  {'@attr': {'rank': '42'},
#   'artist': {'mbid': 'dfe9a7c4-8cf2-47f4-9dcb-d233c2b86ec3',
#              'name': 'Amy Winehouse',
#              'url': 'https://www.last.fm/music/Amy+Winehouse'},
#   'duration': '216',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/5239865b629b4ec1ab5af616b133d032.png',
#              'size': 'extralarge'}],
#   'mbid': 'e459d6e2-0390-417b-827f-aa14dbb02a0c',
#   'name': "You Know I'm No Good",
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Amy+Winehouse/_/You+Know+I%27m+No+Good'},
#  {'@attr': {'rank': '43'},
#   'artist': {'mbid': 'f27ec8db-af05-4f36-916e-3d57f91ecf5e',
#              'name': 'Michael Jackson',
#              'url': 'https://www.last.fm/music/Michael+Jackson'},
#   'duration': '358',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7a9b0f69d51f41a888ef29df9cfe3594.png',
#              'size': 'extralarge'}],
#   'mbid': 'e25d1292-ca82-4225-ae7d-04193904f3d0',
#   'name': 'Thriller',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Michael+Jackson/_/Thriller'},
#  {'@attr': {'rank': '44'},
#   'artist': {'mbid': '6f6fd596-76e0-4b82-aa37-f558ac2d337b',
#              'name': 'Gotye',
#              'url': 'https://www.last.fm/music/Gotye'},
#   'duration': '294',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/b6fdbb0056dc9db3c19023a2b513df56.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/b6fdbb0056dc9db3c19023a2b513df56.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/b6fdbb0056dc9db3c19023a2b513df56.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/b6fdbb0056dc9db3c19023a2b513df56.png',
#              'size': 'extralarge'}],
#   'mbid': '5b6ad1ba-9e08-4570-bcef-e3343519070a',
#   'name': 'Somebody That I Used To Know',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Gotye/_/Somebody+That+I+Used+To+Know'},
#  {'@attr': {'rank': '45'},
#   'artist': {'mbid': '69ee3720-a7cb-4402-b48d-a02c366f2bcf',
#              'name': 'The Cure',
#              'url': 'https://www.last.fm/music/The+Cure'},
#   'duration': '214',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/c0246a80dd73471f83e56c569fd47a7e.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/c0246a80dd73471f83e56c569fd47a7e.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/c0246a80dd73471f83e56c569fd47a7e.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/c0246a80dd73471f83e56c569fd47a7e.png',
#              'size': 'extralarge'}],
#   'mbid': '8d9104c6-7d8e-460b-8c3d-2d797f79953d',
#   'name': "Friday I'm in Love",
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/The+Cure/_/Friday+I%27m+in+Love'},
#  {'@attr': {'rank': '46'},
#   'artist': {'mbid': '650e7db6-b795-4eb5-a702-5ea2fc46c848',
#              'name': 'Lady Gaga',
#              'url': 'https://www.last.fm/music/Lady+Gaga'},
#   'duration': '277',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/611fe7f96da2b6b40a0deccef673199d.png',
#              'size': 'extralarge'}],
#   'mbid': '0810268f-2e52-4f89-86be-42762ea3f6d4',
#   'name': 'Just Dance',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Lady+Gaga/_/Just+Dance'},
#  {'@attr': {'rank': '47'},
#   'artist': {'mbid': 'a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432',
#              'name': 'U2',
#              'url': 'https://www.last.fm/music/U2'},
#   'duration': '296',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/2368d78350d34561914609a9cecd1b52.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/2368d78350d34561914609a9cecd1b52.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/2368d78350d34561914609a9cecd1b52.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/2368d78350d34561914609a9cecd1b52.png',
#              'size': 'extralarge'}],
#   'mbid': '6b9a509f-6907-4a6e-9345-2f12da09ba4b',
#   'name': 'With or Without You',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/U2/_/With+or+Without+You'},
#  {'@attr': {'rank': '48'},
#   'artist': {'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#              'name': 'Coldplay',
#              'url': 'https://www.last.fm/music/Coldplay'},
#   'duration': '222',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/76b29fb461e74a48bab4686e0269421b.png',
#              'size': 'extralarge'}],
#   'mbid': 'ba4bcf45-fcdf-4ff7-a19e-be3fdffae337',
#   'name': 'Violet Hill',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Coldplay/_/Violet+Hill'},
#  {'@attr': {'rank': '49'},
#   'artist': {'mbid': '5d02f264-e225-41ff-83f7-d9b1f0b1874a',
#              'name': 'Simon & Garfunkel',
#              'url': 'https://www.last.fm/music/Simon+&+Garfunkel'},
#   'duration': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/3426724f0f044abda4e4311f3b5c82d9.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/3426724f0f044abda4e4311f3b5c82d9.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/3426724f0f044abda4e4311f3b5c82d9.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/3426724f0f044abda4e4311f3b5c82d9.png',
#              'size': 'extralarge'}],
#   'mbid': '',
#   'name': 'The Sound of Silence',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/Simon+&+Garfunkel/_/The+Sound+of+Silence'},
#  {'@attr': {'rank': '50'},
#   'artist': {'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#              'name': 'The Beatles',
#              'url': 'https://www.last.fm/music/The+Beatles'},
#   'duration': '259',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/774177d77ee348e198bee6d223a22ff3.png',
#              'size': 'small'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/774177d77ee348e198bee6d223a22ff3.png',
#              'size': 'medium'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/774177d77ee348e198bee6d223a22ff3.png',
#              'size': 'large'},
#             {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/774177d77ee348e198bee6d223a22ff3.png',
#              'size': 'extralarge'}],
#   'mbid': '485bbe7f-d0f7-4ffe-8adb-0f1093dd2dbf',
#   'name': 'Come Together',
#   'streamable': {'#text': '0', 'fulltrack': '0'},
#   'url': 'https://www.last.fm/music/The+Beatles/_/Come+Together'}]

# %%
tracks_df = pd.DataFrame({'rank':[],
                          'artist_name':[],
                          'song_name':[]
                         })
for track in tracks:
    tracks_df['rank'].append(track['@attr']['rank'])
    tracks_df['artist_name'].append(['artist']['name'])
    tracks_df['song_name'].append(track['name'])
tracks_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-618b07ee2a70> in <module>()
#       4                          })
#       5 for track in tracks:
# ----> 6     tracks_df['rank'].append(track['@attr']['rank'])
#       7     tracks_df['artist_name'].append(['artist']['name'])
#       8     tracks_df['song_name'].append(track['name'])
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/series.py in append(self, to_append, ignore_index, verify_integrity)
#    2154             to_concat = [self, to_append]
#    2155         return concat(to_concat, ignore_index=ignore_index,
# -> 2156                       verify_integrity=verify_integrity)
#    2157
#    2158     def _binop(self, other, func, level=None, fill_value=None):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     284                        ' only pd.Series, pd.DataFrame, and pd.Panel'
#     285                        ' (deprecated) objs are valid'.format(type(obj)))
# --> 286                 raise TypeError(msg)
#     287
#     288             # consolidate
#
# TypeError: cannot concatenate object of type "<class 'str'>"; only pd.Series, pd.DataFrame, and pd.Panel (deprecated) objs are valid
