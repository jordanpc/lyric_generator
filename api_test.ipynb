# %%
import pandas as pd
import os
import numpy as np
import datetime as dt
import requests
from pprint import pprint

# %%
base_url = "http://ws.audioscrobbler.com/2.0/"

params = {
    'method': 'chart.gettoptracks',
    'api_key': "a36164605f7b8a872199705e0d6552b2",
    'format': 'json'
}

# %%
track_response = requests.get(base_url, params=params)
track_json = track_response.json()
pprint(track_json)
# Out:
# {'tracks': {'@attr': {'page': '1',
#                       'perPage': '50',
#                       'total': '22980715',
#                       'totalPages': '459615'},
#             'track': [{'artist': {'mbid': '164f0d73-1234-4e2c-8743-d77bf2191051',
#                                   'name': 'Kanye West',
#                                   'url': 'https://www.last.fm/music/Kanye+West'},
#                        'duration': '0',
#                        'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/fdc360d18ba0d6d06bad8d08e9a5d4c0.png',
#                                   'size': 'small'},
#                                  {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/fdc360d18ba0d6d06bad8d08e9a5d4c0.png',
#                                   'size': 'medium'},
#                                  {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/fdc360d18ba0d6d06bad8d08e9a5d4c0.png',
#                                   'size': 'large'},
# ...

# %%
title = []
artist = []
playcount = []
listeners = []

for track in track_json:
    title.append(tracks)
